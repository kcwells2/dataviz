# %%
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt
import ipywidgets as widgets
import traitlets
import pandas as pd
import numpy as np
import re
import bqplot
from bqplot import (
    OrdinalScale, LinearScale, Bars, Lines, Axis, Figure
)
#from wordcloud import WordCloud, STOPWORDS
plt.rcParams["figure.figsize"] = (16, 10)

# %%
data = pd.read_csv("movie_sample.csv", sep=None)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#            reviewerID        asin  \
# 0       AV6QDP8Q0ONK4  B001AYWY9K
# 1      A1M4NJYP0WNL8Q  B0000D9BEB
# 2      A100RW34WSLTUW  B004K4FUUC
# 3       AQZ0K4JCHIHBV  630336473X
# 4      A1GKTHLZOWBLKL  B005LAIIMG
# 5      A3EHYVC35E5WRG  B002ZG9864
# 6      A30X6EFTCNAJ7C  B002AMW108
# 7      A3KF4IP2MUS8QQ  B001VC99HG
# 8      A2Z2MUZ76N5EY7  B0000AUHOD
# 9       AFLVXJNQLBTXW  630264187X
# 10     A2PDC6SESC021Q  B00003CXXR
# 11     A313EYJS0XB22Q  B00BQXTC54
# 12     A27MOT4ZIUAKIW  B0012IX35I
# 13     A19ELFMMKB83HC  0782010059
# 14     A3AQ6590YBDSNV  B00007GZPE
# 15     A31I1FERUMXCXA  B000EGDAF2
# 16     A1AO3L476K5SI0  B0001MMF4G
# 17     A2RYY7YJAT5OZ8  6305285861
# 18     A27W5AJNP6YX7Z  B0006FO8NY
# 19     A3NH7PYU4AD5GA  B00JBBJJ24
# 20     A19MF2JPE34HFC  B006W9KNXC
# 21      A106016KSI0YQ  6305010633
# 22     A30N28B8FYZECJ  B001PPGAIA
# 23     A2GXKHLB4F48CW  6300988805
# 24     A3UAH7LJRNX6PJ  6302380561
# 25     A33L3J8HZV8IEW  6304580878
# 26     A275WB4PYH6227  6305949662
# 27      A1BWZYMC7GTR0  B0009MAPVS
# 28     A2SZJV9I4670KZ  B00FKN1GJQ
# 29     A34I966792JQEV  B000BYA5G4
# ...               ...         ...
# 49970   AKS9SJTHTU0OM  1574925628
# 49971  A31RM5QU797HPJ  0783222955
# 49972   ABQUJ3Z6EP5GN  B007KAUWO2
# 49973  A1P7O2PAA8H1DD  B000JYW5DM
# 49974  A2LP1OFQTK5MY6  6301801709
# 49975   ADB8XCKNSDY5Z  6303407188
# 49976  A1KAS2W1TD8UOU  B00BUUAV08
# 49977   ANIKSP8JGPB0N  B0038N9X3G
# 49978  A296A1BJ0W7AM2  B00005N5SD
# 49979   AYB4WITL5PE4A  B006Z94HWM
# 49980   AZ1UFPNARPZD2  6305161933
# 49981  A24ZPSLOOM1O2M  0784011796
# 49982   A8F3SXF1H6YIJ  6302643627
# 49983   AJAZLHS8NE9O9  B00B52F278
# 49984  A2UUP58XPQW3GF  B001VBM0Z0
# 49985  A2LTYU8UINTF2E  B001UV4XIS
# 49986  A2E3MEAPBSX4F2  B008JFUOWM
# 49987  A2X7ZJ4QXF1IZ6  6301285085
# 49988   AQP1VPK16SVWM  B001CQONOA
# 49989  A3TA8OZKLWKV01  B0009FU0ZQ
# 49990  A2NMY5UF624JGE  B006X040NY
# 49991  A38OK3TV4X3GZB  B000EHSVG4
# 49992   A73K4WUW64LYD  B009MAQWRE
# 49993  A3DS5AREACSS9F  B007G8SEF2
# 49994  A14M5W3LKDTLN8  B004O5N3QU
# 49995  A1HUDHPQFZYHQW  B00005JKEC
# 49996   A59NEDTG1DHG7  B003L1Z33Y
# 49997  A280GY5UVUS2QH  B006PTL1GC
# 49998   A8DI0COTCMRDV  B000YOX3HE
# 49999  A1YQ6QB2127AJ4  B0002W4UDE
#
#                                            reviewerName  \
# 0                    The Movie Guy "Movies from A to Z"
# 1                Marc Ruby&#8482; "The Noh Hare&#8482;"
# 2                                           Jesse Beitz
# 3                                      Kristin Rattigan
# 4                                        Cidney Webster
# 5                                               Valmina
# 6                                       Dbzgirl "Rosie"
# 7                            Daniel Jolley "darkgenius"
# 8                                      James E. Carroll
# 9                                Ayrton Roberto Pastore
# 10                                               Daniel
# 11                           Marie A. Urquhart "Maggie"
# 12                                    The Jaundiced Eye
# 13                                J. Carey "waymorefun"
# 14                               David Seguin "djzilla"
# 15                                                    C
# 16                            G. Bowden "Movie buff..."
# 17                              European Book Treasurer
# 18                                  Ivy Bewley "Hiedra"
# 19                                         H. Schneider
# 20                                          candemonium
# 21                                          Jay Dickson
# 22                                Elizabeth J. Brookman
# 23                              trastevere "trastevere"
# 24                                       Plenty O'Toole
# 25                                          Holden Punk
# 26                                 Mian Sukiman "M Suk"
# 27                Showstopper "Showstopper Loves Bella"
# 28                             michael joseph "michael"
# 29                                          Joseph Izzo
# ...                                                 ...
# 49970                                         K. Gordon
# 49971                                   Amazon Customer
# 49972                              John's Horror Corner
# 49973                                          Blade329
# 49974                                        P. Trusten
# 49975                                       theboombody
# 49976                                    simple sellers
# 49977                                           pmardis
# 49978                                      Dave Barbara
# 49979                                              WV77
# 49980                     Jeffrey Ellis "bored recluse"
# 49981                               runner30 "runner30"
# 49982                                        LiLKidneys
# 49983                                               ALF
# 49984                               Woopak "The THRILL"
# 49985                                     P. Djiwatampu
# 49986                            Linda Novack "Linda S"
# 49987                                   Flame "booklvr"
# 49988  Wayne Klein "If at first the idea is not absu...
# 49989              Russell B. Benedetti "R.B,Benedetti"
# 49990                   Diamond M. Dominguez "diamon2x"
# 49991                                           MATTJ22
# 49992                                            Chouji
# 49993           Amazon Customer "Writer/Reader/Watcher"
# 49994                                     John A. Parks
# 49995                        eugenia maldonado "2nd WW"
# 49996                                  Addicted2Amazon!
# 49997                                     Doug Anderson
# 49998                                       creatureart
# 49999                                    David Anderson
#
#                                               reviewText  overall  \
# 0      ** Early plot spoilers**I am not a fan of Tim ...        2
# 1      This is the second DVD in a series that is pro...        5
# 2      Wonderful series that reminds me of the Elizab...        5
# 3      This sounds like a more modern movie and many ...        3
# 4      Let's get one thing straight: this is not a zo...        3
# 5      Cute movie. Really funny. Tom and Cameron are ...        5
# 6      I've watched most of the episodes of "Flapjack...        3
# 7      Come on down to Florida for some good old-fash...        4
# 8      Albert Finney's portrayal of retiring classics...        4
# 9      I am collector of moviesThe master Bergman sho...        5
# 10     Jurassic Park, it is one of the greatest sci-f...        5
# 11     L really liked this series.  The characters ar...        5
# 12     It is rare that I am at a loss for words, but ...        1
# 13     John Wayne and Maureen Ohara directed by John ...        5
# 14     Denise is one of those unique fitness gurus.  ...        4
# 15     This series is Awesome I can't belive it's com...        4
# 16     I've only seen this movie through MST3K when i...        3
# 17     I'm glad US public is getting introduced to Ru...        4
# 18     I am a huge Jennifer Jones fan, and that is wh...        4
# 19     This allegorical dystopia has the whole surviv...        5
# 20     Everyone knows why Downton Abbey is so beloved...        5
# 21     Movie musicals were guaranteed box-office duri...        3
# 22     Bought it after reading Amazon reviews. Agree ...        5
# 23     It doesn't hurt that the story is one of the g...        5
# 24     From Russia With Love is the second of the Bon...        5
# 25     This film is good for a giggle. Not a classic,...        4
# 26     You have to sit through at least an hour of th...        2
# 27     Hello and welcome to my review on Judgement Da...        3
# 28     it was good and funny not much else to say.I a...        4
# 29     Works as a great piece of filmaking on its own...        5
# ...                                                  ...      ...
# 49970  I'm shocked to say I found this 3 hour TV mini...        5
# 49971  Atticus Flich (Peck) is a lawyer who is defend...        5
# 49972  Lots of well-quipped laughs.  Love Woody Harre...        4
# 49973  This movie easily ranks on my top 10 list of b...        1
# 49974  While this is a slow movie if you are not a ha...        5
# 49975  What a pleasant surprise this movie turned out...        5
# 49976  love the reflective slow burn and symbolism th...        5
# 49977  HAS GOT TO BE ON OF THE ALL TIME BEST ACTED UN...        5
# 49978  It is not up to the to the same quality conten...        3
# 49979  After waiting for brand new releases of more S...        5
# 49980  I'm like a lot of people in that I first disco...        4
# 49981  Don't rush out to see it, it's really just a v...        2
# 49982  I have loved this series since I first saw it ...        5
# 49983  I love this series,  it gives a good taste of ...        5
# 49984  From the award-winning director of the critica...        4
# 49985  Very sad that the franchise has over but this ...        5
# 49986  Fantastic.  I love all of these movies.  I did...        5
# 49987  Since I had seen this movie.  I forgot how har...        5
# 49988  "The Wild Wild West" was a terrific show. CBS/...        3
# 49989  I purchase the complete series including Stone...        5
# 49990  I love this movie.  After Pierce Brosnan stopp...        5
# 49991  i like teenage mutant ninja turtles. i plan to...        4
# 49992  I watched the first two episodes online just t...        5
# 49993  I never got to see much of this one when I was...        4
# 49994  Kaufmann is brilliant and Magee is superb.  Sh...        5
# 49995  Ah, what a great film it is and what a prodigi...        5
# 49996  Wow.  So I KNEW what I was getting into.  All ...        5
# 49997  This is really a story of Victorian restraints...        5
# 49998  WOW! What a treat for both the fans of Star Wa...        5
# 49999  "Stepford Wives" is a 2004 remake of the origi...        4
#
#                                                  summary  unixReviewTime  \
# 0                         THE SOUND OF ONE HAND CLAPPING      1288137600
# 1                                      Angels and Devils      1071878400
# 2                                 Like Elizabeth Gaskill      1393632000
# 3                Our Little Girl-we don't care about her       997574400
# 4                              Perfect Popcorn for Prime      1402704000
# 5                                              Fun Movie      1378857600
# 6          "The Marvelous Misadventures of Flapjack" DVD      1247702400
# 7      A highly predictable yet entertaining film wit...      1313193600
# 8                                          A Superb Film      1074038400
# 9                                 delivery went smoothly      1382572800
# 10                                                   ...      1031961600
# 11                                    ish there was more      1399161600
# 12     Astoundingly Awful.....No words can convey jus...      1216598400
# 13                        One of the Dukes best westerns      1276387200
# 14      Austinized Yoga...or Denise's Fat Burning System      1057968000
# 15                                 LIFE GOES ON TO DVD!!      1139270400
# 16               Lots of padding...and Touch Conners!!!.      1171152000
# 17                                                 Movie      1170720000
# 18                  Laurence Olivier over Eddie Albert??      1354320000
# 19                                   Take it or leave it      1405555200
# 20                               The best of the best...      1374883200
# 21                                     Only Make-Believe      1217462400
# 22                                              Love it!      1240617600
# 23                        David Lean's most perfect film      1329696000
# 24     Thank you Russia for giving us this movie with...       959558400
# 25       A witty film for young adults in the real world      1153008000
# 26                     A surprise ending save this movie       965174400
# 27                                    Judgement Day 2005      1124323200
# 28                                                  good      1383782400
# 29                                        Fantastic Film      1152403200
# ...                                                  ...             ...
# 49970                         Far better than I expected      1319846400
# 49971      &quot;In the name of God, do your duty!&quot;      1057017600
# 49972  Lots of well-quipped laughs.  Love Woody Harre...      1337644800
# 49973                         As bad as a movie can get.      1288310400
# 49974                             It is what it is...LOL      1398384000
# 49975            Wonderful Film.  Makes you feel for Ed.      1167609600
# 49976                            the house that built me      1366070400
# 49977          ONE OF THE GREAT CHICK FLICKS OF OUR TIME      1404691200
# 49978                                            It's OK      1365465600
# 49979                             New Releases! Finally!      1329696000
# 49980                                           Gripping      1017014400
# 49981                             very good student film      1013904000
# 49982  Far more moving and enlightening than "Passion...      1264636800
# 49983                                        Good series      1386028800
# 49984  4  Stars: Mamoru Oshii's Best Film Since the O...      1243382400
# 49985                                    Very good movie      1355097600
# 49986  Fastastic, thy arel geat actors.  I always lik...      1387065600
# 49987                                It's been years ...      1395878400
# 49988  Four stars for all four seasons, 2 stars for t...      1226361600
# 49989                            Tom Selleck :Stone Cold      1377907200
# 49990                                    Love this movie      1388448000
# 49991                                         tmnt vol 4      1352764800
# 49992                                 Entertaining Anime      1381017600
# 49993                           ABC's version of STARMAN      1344297600
# 49994  Kaufmann and Magee make this excitilng even af...      1358208000
# 49995                                         Unexpected      1381881600
# 49996           CRAZY Hard Workout for a CRAZY Hot Body!      1376956800
# 49997                                      Ego versus Id      1327104000
# 49998            A Star Wars/Family Guy Fans Wet Dream !      1200614400
# 49999                     The Funny Side of the Original      1101340800
#
#         reviewTime  helpful1  helpful2
# 0      10 27, 2010         1         1
# 1      12 20, 2003         9        10
# 2       03 1, 2014         0         0
# 3      08 12, 2001         7         9
# 4      06 14, 2014         1         2
# 5      09 11, 2013         0         0
# 6      07 16, 2009         2        82
# 7      08 13, 2011         0         0
# 8      01 14, 2004        31        31
# 9      10 24, 2013         0         0
# 10     09 14, 2002         0         1
# 11      05 4, 2014         0         0
# 12     07 21, 2008        11        12
# 13     06 13, 2010         3         4
# 14     07 12, 2003         5         6
# 15      02 7, 2006        12        15
# 16     02 11, 2007         1         4
# 17      02 6, 2007         1         1
# 18      12 1, 2012         1         1
# 19     07 17, 2014         1         1
# 20     07 27, 2013         0         0
# 21     07 31, 2008         3         3
# 22     04 25, 2009         0         0
# 23     02 20, 2012         2         2
# 24     05 29, 2000         0         1
# 25     07 16, 2006         4         4
# 26      08 2, 2000         2         4
# 27     08 18, 2005         4         4
# 28      11 7, 2013         2         3
# 29      07 9, 2006         2         5
# ...            ...       ...       ...
# 49970  10 29, 2011         2         2
# 49971   07 1, 2003         1         1
# 49972  05 22, 2012         7        10
# 49973  10 29, 2010         2         4
# 49974  04 25, 2014         1         1
# 49975   01 1, 2007         5         6
# 49976  04 16, 2013         0         0
# 49977   07 7, 2014         0         0
# 49978   04 9, 2013         0         0
# 49979  02 20, 2012        32        35
# 49980  03 25, 2002         0         0
# 49981  02 17, 2002         4         7
# 49982  01 28, 2010         1         1
# 49983   12 3, 2013         0         0
# 49984  05 27, 2009        25        30
# 49985  12 10, 2012         0         0
# 49986  12 15, 2013         0         0
# 49987  03 27, 2014         0         0
# 49988  11 11, 2008       259       274
# 49989  08 31, 2013         0         0
# 49990  12 31, 2013         0         0
# 49991  11 13, 2012         0         0
# 49992   10 6, 2013         2         3
# 49993   08 7, 2012         1         2
# 49994  01 15, 2013         0         1
# 49995  10 16, 2013         0         0
# 49996  08 20, 2013         5         5
# 49997  01 21, 2012        67        74
# 49998  01 18, 2008         3         4
# 49999  11 25, 2004         1         2
#
# [50000 rows x 10 columns]

# %%
df = pd.DataFrame(data.reviewTime.str.split(',',2).tolist(),
                                   columns = ['Day/Month','year'])
data["year"] = df["year"]

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------------------
#
#
#
#
# # Words

# %%
def getWords(text):
    return re.compile('\w+').findall(text)

test = getWords(data["reviewText"].to_string())

from collections import Counter

wordcount = Counter(test)

#wordcount.most_common(10)

# %%
#done on local machine dont run until word cloud is installed
from wordcloud import WordCloud, STOPWORDS
kam = ' '.join(test)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(collocations=False, background_color="white", max_font_size=200, stopwords=stopwords).generate(kam)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### This is a wordcloud made of the most popular words that appeared in the dataset amazon movie reviews. This was created using the wordcloud package. As the words that appear larger have more appearances in dataset while smaller words appear less times. The colors are the default colors except we set the background color to white to make it easier to read.

# %% [markdown]
# ## --------------------------------------------------------------------------------------------------------------------------------
#
#
#
#
# # Movies per year

# %%
from IPython.display import display 
from collections import Counter

# %%
#youll have to run this cell to show plot

import ipywidgets as widgets
from collections import Counter
df2 = data.groupby("year")
#@ipywidgets.interact(yr = [i for i in range(1998,2014)])
yr = widgets.Dropdown(options=[i for i in range(1998,2015)],value=1998,description='yr',disabled=False)
def draw_movie_number(yr):
    t = df2.get_group(' %s' % yr)
    c = Counter(t["overall"])
    it = c.items()
    key = [i[0] for i in it]
    value = [i[1] for i in it]
    plt.xlabel("Overall")
    plt.ylabel("Movie_number")
    size = 2**2
    
    plt.bar(c.keys(), c.values())
    plt.show()
    
    
    

widgets.interactive(draw_movie_number,yr = yr)
# Out:
# interactive(children=(Dropdown(description='yr', options=(1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014), value=1998), Output()), _dom_classes=('widget-interact',))

# %% [markdown]
# ### This is a bar graph to show the reviews per year. This is interactive so that you can see the different years and their values accordinly. This was used doing ipywidgets as well as matplotlib.

# %%
def filter_by_point(data, point):
    point_array = np.array([point]) == np.array(data["overall"])
    return point_array

allpoint = data["year"]
point1 = data["year"][filter_by_point(data, 1)]
point2 = data["year"][filter_by_point(data, 2)]
point3 = data["year"][filter_by_point(data, 3)]
point4 = data["year"][filter_by_point(data, 4)]
point5 = data["year"][filter_by_point(data, 5)]




plt.hist(allpoint,bins=16, alpha=0.25,label="allpoint")
plt.hist(point5,bins=16,alpha=0.5,label="5 points rating")
plt.hist(point4, bins=15, alpha=0.5,label="4 points rating")
plt.hist(point3, bins=16,alpha=0.5,label="3 points rating")
plt.hist(point2, bins=16,alpha=0.5,label="2 points rating")
plt.hist(point1, bins=15,alpha=0.5,label="1 points rating")

plt.xlabel("year",fontsize=15)
plt.ylabel("numbers of points",fontsize=15)


plt.legend()
plt.show()

# %% [markdown]
# ### This also shows the number of ratings per year but shows it over time. The blue is the total number of reviews that happened over the whole dataset while the other colors represent the number of ratings for that specific year. This is not interactive because you wouldnt be able to compare years over time. This was done using matplotlib

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------------------
#
#
#
#
# # Movies per year

# %%
m = data.groupby("year")["overall"].sum()
x = m.index
y = m
plt.title('Number of movies per year')
plt.xlabel("year")
plt.ylabel("Number of Movies")
plt.plot(x,y,linewidth = 6)

# %% [markdown]
# ### This is a visualization of number of movies per year. This is not intereactive because it is supposed to show how movies have increased over time. This was done using matplotlib.

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------
#
#
# # Correlations

# %%
from collections import Counter
import seaborn as sns
import pylab

df = pd.DataFrame(data.reviewTime.str.split(',',2).tolist(), columns = ['Day/Month','year'])
data["year"] = df["year"]

def getWords(text):
    return re.compile('\w+').findall(text)

words = getWords(data["reviewText"].to_string())

totalWords = Counter(words)

selectWords = ["movie", "film", "great", "good", "love", "movies", "first", "series", "story", "DVD", "best",
                  "show", "fan", "loved", "classic", "funny", "favorite", "season", "old", "films", "action", "liked", 
                  "little", "better", "bad", "read", "book", "stars", "must", "TV", "original", "time", "comedy",
                  "horror", "wonderful", "family", "interesting", "plot", "star", "cast"]

count = len(re.findall('\w+', str(selectWords)))

test = data["reviewText"].to_string()

wordlist = data["reviewText"].tolist()
a = data["reviewText"].tolist()

list_of_lists = []
for review in a:
    count_list = []
    #print(count_word)
    for count_word in selectWords:
        count = len(re.findall(count_word, str(review)))
        count_list.append(count)
    list_of_lists.append(count_list)

data2 = pd.DataFrame(list_of_lists, columns = selectWords)

result = pd.concat([data, data2], axis=1, ignore_index=False)

y = result.overall                         
list = ['overall']
x = result.drop(list,axis = 1)

#correlation map that shows which variables are correlated and should be eliminated
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(x.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax, cmap="Blues")
pylab.show()

# %% [markdown]
# ### The graph above shows the correlation of the variables for "overall" review ratings. The darker the cells, the more correlations the variables have between each other. Ignoring the diagonal line, we can detect instances where two variables are highly correlated to each other, which creates multicollinearity when modeling. Therefore, now we know which variables to remove if we were to create a statistical model.

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------
#
#
# # Movie Genres Over Time

# %%
import pandas
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

import seaborn as sns

df = result[['year', 'funny', 'comedy', 'horror', 'family', 'TV', 'classic', 'original', 'action']]
df2 = df.groupby("year")[['funny', 'comedy', 'horror', 'family', 'TV', 'classic', 'original', 'action']].sum()
df2 = df2.reset_index()
    

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20, 20))
 
# create a color palette
palette = plt.get_cmap('Set1')
 
# multiple line plot
num=0
for column in df2.drop('year', axis=1):
    num = num + 1
    plt.plot(df2['year'], df2[column], marker='', color=palette(num), linewidth=5, alpha=0.9, label=column)

# Add legend
plt.legend(loc=2, ncol=2, prop={'size': 20})


# Add titles
plt.title("Movie Genres Over Time", loc='left', fontsize=40, fontweight=0, color='black')
plt.xlabel("Time", fontsize = 30)
plt.ylabel("Score", fontsize = 30)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
pylab.show()

# %% [markdown]
# ### We took the keywords and made them into variables and then proceeded to create a time series plot. It seems that ther was very little data for movies from 1998, or perhaps Amazon just doesn't offer many movies from those time periods. But we can see that Amazon movies had a huge increase across all genres in 2005, and then another one in 2013, which almost doubled in increase compared to 2005. But, it seems that the genres are all drastically decreasing by 2014, which could mean a new genre was invented, or not enough data was provided.
